# %%
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
freeform = pd.read_csv("../assets/project3/2025/freeFormResponses.csv", low_memory=False)

# %%
multiple = pd.read_csv("../assets/project3/2025/multipleChoiceResponses.csv", low_memory=False)

# %%
freeform = freeform.rename(columns={"Q32_OTHER": "Q32_OTHER_TEXT"})

# %%
multiple = multiple.rename(columns={"Q32_OTHER": "Q32_OTHER_TEXT"})

# %%
multiple = multiple.drop(columns=["Q12_MULTIPLE_CHOICE"])

# %%
multiple.to_csv("../assets/project3/2025/multiple_choice_responses.csv", index=0)

# %%
freeform.to_csv("../assets/project3/2025/freeform_responses.csv", index=0)
